# %%
# Import the dependencies.
from citipy import citipy
import requests
from config import weatherkey

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weatherkey

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a set of random latitutde and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | burnie
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | bakel
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | kavieng
# Processing Record 7 of Set 1 | russell
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | nome
# Processing Record 11 of Set 1 | cabo san lucas
# Processing Record 12 of Set 1 | bethel
# Processing Record 13 of Set 1 | marzuq
# Processing Record 14 of Set 1 | chokurdakh
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | datong
# Processing Record 21 of Set 1 | deputatskiy
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | grindavik
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | prince rupert
# Processing Record 29 of Set 1 | geraldton
# Processing Record 30 of Set 1 | belyy yar
# Processing Record 31 of Set 1 | cheuskiny
# City not found. Skipping...
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | nioro
# Processing Record 34 of Set 1 | batagay-alyta
# Processing Record 35 of Set 1 | wenatchee
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 1 | krasnoselkup
# Processing Record 39 of Set 1 | vardo
# Processing Record 40 of Set 1 | ilulissat
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | aksarayskiy
# Processing Record 44 of Set 1 | pevek
# Processing Record 45 of Set 1 | verkhnyaya inta
# Processing Record 46 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | smidovich
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | okha
# Processing Record 1 of Set 2 | asfi
# Processing Record 2 of Set 2 | buta
# Processing Record 3 of Set 2 | jalu
# Processing Record 4 of Set 2 | margate
# Processing Record 5 of Set 2 | wundanyi
# Processing Record 6 of Set 2 | faanui
# Processing Record 7 of Set 2 | touros
# Processing Record 8 of Set 2 | fare
# Processing Record 9 of Set 2 | kedzierzyn-kozle
# Processing Record 10 of Set 2 | chicama
# Processing Record 11 of Set 2 | tuktoyaktuk
# Processing Record 12 of Set 2 | sumbawanga
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | khatanga
# Processing Record 15 of Set 2 | bambous virieux
# Processing Record 16 of Set 2 | pisco
# Processing Record 17 of Set 2 | upernavik
# Processing Record 18 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 2 | venice
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | honningsvag
# Processing Record 22 of Set 2 | nikolskoye
# Processing Record 23 of Set 2 | severo-kurilsk
# Processing Record 24 of Set 2 | lethem
# Processing Record 25 of Set 2 | torbay
# Processing Record 26 of Set 2 | haines junction
# Processing Record 27 of Set 2 | mahenge
# Processing Record 28 of Set 2 | puerto maldonado
# Processing Record 29 of Set 2 | airai
# Processing Record 30 of Set 2 | loa janan
# Processing Record 31 of Set 2 | kralendijk
# Processing Record 32 of Set 2 | kegayli
# City not found. Skipping...
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | natal
# Processing Record 35 of Set 2 | mount gambier
# Processing Record 36 of Set 2 | kodiak
# Processing Record 37 of Set 2 | richards bay
# Processing Record 38 of Set 2 | hithadhoo
# Processing Record 39 of Set 2 | longonjo
# Processing Record 40 of Set 2 | chuy
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | antofagasta
# Processing Record 43 of Set 2 | porto velho
# Processing Record 44 of Set 2 | longyearbyen
# Processing Record 45 of Set 2 | vicuna
# Processing Record 46 of Set 2 | batouri
# Processing Record 47 of Set 2 | monte alegre
# Processing Record 48 of Set 2 | rio bananal
# Processing Record 49 of Set 2 | port augusta
# Processing Record 50 of Set 2 | brewster
# Processing Record 1 of Set 3 | bredasdorp
# Processing Record 2 of Set 3 | asau
# Processing Record 3 of Set 3 | mar del plata
# Processing Record 4 of Set 3 | oroville
# Processing Record 5 of Set 3 | bandarbeyla
# Processing Record 6 of Set 3 | esperance
# Processing Record 7 of Set 3 | kahului
# Processing Record 8 of Set 3 | qaanaaq
# Processing Record 9 of Set 3 | havelock
# Processing Record 10 of Set 3 | scarborough
# Processing Record 11 of Set 3 | puranpur
# Processing Record 12 of Set 3 | guider
# Processing Record 13 of Set 3 | namatanai
# Processing Record 14 of Set 3 | ukiah
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | te anau
# Processing Record 17 of Set 3 | lanxi
# Processing Record 18 of Set 3 | roches noires
# City not found. Skipping...
# Processing Record 19 of Set 3 | tecpan
# Processing Record 20 of Set 3 | yala
# Processing Record 21 of Set 3 | kropotkin
# Processing Record 22 of Set 3 | cam ranh
# Processing Record 23 of Set 3 | ingham
# Processing Record 24 of Set 3 | ventspils
# Processing Record 25 of Set 3 | astana
# Processing Record 26 of Set 3 | balabac
# Processing Record 27 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 29 of Set 3 | marfino
# Processing Record 30 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 3 | srednekolymsk
# Processing Record 32 of Set 3 | taoudenni
# Processing Record 33 of Set 3 | kashi
# Processing Record 34 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 3 | sakakah
# Processing Record 36 of Set 3 | yulara
# Processing Record 37 of Set 3 | kattivakkam
# Processing Record 38 of Set 3 | lumberton
# Processing Record 39 of Set 3 | maldonado
# Processing Record 40 of Set 3 | butaritari
# Processing Record 41 of Set 3 | opuwo
# Processing Record 42 of Set 3 | iqaluit
# Processing Record 43 of Set 3 | san-pedro
# Processing Record 44 of Set 3 | tamandare
# Processing Record 45 of Set 3 | teguldet
# Processing Record 46 of Set 3 | ribeira brava
# Processing Record 47 of Set 3 | the valley
# Processing Record 48 of Set 3 | padang
# Processing Record 49 of Set 3 | sur
# Processing Record 50 of Set 3 | mbumi
# Processing Record 1 of Set 4 | hervey bay
# Processing Record 2 of Set 4 | zhicheng
# Processing Record 3 of Set 4 | port lincoln
# Processing Record 4 of Set 4 | borogontsy
# Processing Record 5 of Set 4 | kaitangata
# Processing Record 6 of Set 4 | san patricio
# Processing Record 7 of Set 4 | mehamn
# Processing Record 8 of Set 4 | provideniya
# Processing Record 9 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 4 | wheatley
# Processing Record 11 of Set 4 | riachao das neves
# Processing Record 12 of Set 4 | kizhinga
# Processing Record 13 of Set 4 | saskylakh
# Processing Record 14 of Set 4 | funtua
# Processing Record 15 of Set 4 | port elizabeth
# Processing Record 16 of Set 4 | emerald
# Processing Record 17 of Set 4 | beloha
# Processing Record 18 of Set 4 | banjar
# Processing Record 19 of Set 4 | saint george
# Processing Record 20 of Set 4 | marigot
# Processing Record 21 of Set 4 | ponta do sol
# Processing Record 22 of Set 4 | kutum
# Processing Record 23 of Set 4 | genc
# Processing Record 24 of Set 4 | bengkulu
# Processing Record 25 of Set 4 | tiksi
# Processing Record 26 of Set 4 | kang
# Processing Record 27 of Set 4 | bushehr
# Processing Record 28 of Set 4 | hasaki
# Processing Record 29 of Set 4 | tukrah
# Processing Record 30 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 31 of Set 4 | benalla
# Processing Record 32 of Set 4 | luderitz
# Processing Record 33 of Set 4 | ormara
# Processing Record 34 of Set 4 | dalbandin
# Processing Record 35 of Set 4 | rio grande
# Processing Record 36 of Set 4 | palmar
# Processing Record 37 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 4 | flin flon
# Processing Record 39 of Set 4 | nkhata bay
# Processing Record 40 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 4 | bilibino
# Processing Record 42 of Set 4 | aripuana
# Processing Record 43 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 4 | baykit
# Processing Record 45 of Set 4 | xai-xai
# Processing Record 46 of Set 4 | beihai
# Processing Record 47 of Set 4 | lompoc
# Processing Record 48 of Set 4 | tazovskiy
# Processing Record 49 of Set 4 | matara
# Processing Record 50 of Set 4 | carnarvon
# Processing Record 1 of Set 5 | kruisfontein
# Processing Record 2 of Set 5 | kijang
# Processing Record 3 of Set 5 | karakol
# Processing Record 4 of Set 5 | varzea da palma
# Processing Record 5 of Set 5 | georgetown
# Processing Record 6 of Set 5 | wajid
# Processing Record 7 of Set 5 | new norfolk
# Processing Record 8 of Set 5 | aksarka
# Processing Record 9 of Set 5 | moree
# Processing Record 10 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 11 of Set 5 | castanos
# Processing Record 12 of Set 5 | birao
# Processing Record 13 of Set 5 | conde
# Processing Record 14 of Set 5 | necochea
# Processing Record 15 of Set 5 | najran
# Processing Record 16 of Set 5 | chesma
# Processing Record 17 of Set 5 | verin
# Processing Record 18 of Set 5 | andenes
# Processing Record 19 of Set 5 | tasiilaq
# Processing Record 20 of Set 5 | narsaq
# Processing Record 21 of Set 5 | smithers
# Processing Record 22 of Set 5 | bathsheba
# Processing Record 23 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 5 | la macarena
# Processing Record 25 of Set 5 | nuuk
# Processing Record 26 of Set 5 | ossora
# Processing Record 27 of Set 5 | souillac
# Processing Record 28 of Set 5 | helong
# Processing Record 29 of Set 5 | nabire
# Processing Record 30 of Set 5 | siilinjarvi
# Processing Record 31 of Set 5 | dinslaken
# Processing Record 32 of Set 5 | amazar
# Processing Record 33 of Set 5 | ancud
# Processing Record 34 of Set 5 | norman wells
# Processing Record 35 of Set 5 | vao
# Processing Record 36 of Set 5 | victoria
# Processing Record 37 of Set 5 | fairbanks
# Processing Record 38 of Set 5 | zhigansk
# Processing Record 39 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 40 of Set 5 | vaasa
# Processing Record 41 of Set 5 | tuatapere
# Processing Record 42 of Set 5 | tecoanapa
# Processing Record 43 of Set 5 | katsuura
# Processing Record 44 of Set 5 | ugoofaaru
# Processing Record 45 of Set 5 | talcahuano
# Processing Record 46 of Set 5 | fortuna
# Processing Record 47 of Set 5 | luanda
# Processing Record 48 of Set 5 | klaksvik
# Processing Record 49 of Set 5 | seminole
# Processing Record 50 of Set 5 | mareeba
# Processing Record 1 of Set 6 | berlevag
# Processing Record 2 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 6 | castro
# Processing Record 4 of Set 6 | houma
# Processing Record 5 of Set 6 | okhotsk
# Processing Record 6 of Set 6 | chop
# Processing Record 7 of Set 6 | ilinskiy
# Processing Record 8 of Set 6 | port hardy
# Processing Record 9 of Set 6 | goure
# Processing Record 10 of Set 6 | ixtapa
# Processing Record 11 of Set 6 | thilogne
# City not found. Skipping...
# Processing Record 12 of Set 6 | forestville
# Processing Record 13 of Set 6 | alamos
# Processing Record 14 of Set 6 | yarada
# Processing Record 15 of Set 6 | lorengau
# Processing Record 16 of Set 6 | sabya
# Processing Record 17 of Set 6 | mount isa
# Processing Record 18 of Set 6 | chapais
# Processing Record 19 of Set 6 | waipawa
# Processing Record 20 of Set 6 | vila franca do campo
# Processing Record 21 of Set 6 | pokaran
# Processing Record 22 of Set 6 | addi ugri
# City not found. Skipping...
# Processing Record 23 of Set 6 | puerto ayora
# Processing Record 24 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 25 of Set 6 | walvis bay
# Processing Record 26 of Set 6 | mokhotlong
# Processing Record 27 of Set 6 | pishin
# Processing Record 28 of Set 6 | cherskiy
# Processing Record 29 of Set 6 | dikson
# Processing Record 30 of Set 6 | cidreira
# Processing Record 31 of Set 6 | turukhansk
# Processing Record 32 of Set 6 | lebu
# Processing Record 33 of Set 6 | praya
# Processing Record 34 of Set 6 | pionerskiy
# Processing Record 35 of Set 6 | lagoa
# Processing Record 36 of Set 6 | lata
# Processing Record 37 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 38 of Set 6 | maragogi
# Processing Record 39 of Set 6 | kununurra
# Processing Record 40 of Set 6 | mayumba
# Processing Record 41 of Set 6 | waddan
# Processing Record 42 of Set 6 | caravelas
# Processing Record 43 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 6 | rio bravo
# Processing Record 45 of Set 6 | korla
# Processing Record 46 of Set 6 | winburg
# Processing Record 47 of Set 6 | cabra
# Processing Record 48 of Set 6 | hobyo
# Processing Record 49 of Set 6 | constitucion
# Processing Record 50 of Set 6 | ribeira grande
# Processing Record 1 of Set 7 | araouane
# Processing Record 2 of Set 7 | bekhtery
# Processing Record 3 of Set 7 | songea
# Processing Record 4 of Set 7 | wittmund
# Processing Record 5 of Set 7 | nicholasville
# Processing Record 6 of Set 7 | barahona
# Processing Record 7 of Set 7 | buala
# Processing Record 8 of Set 7 | vila velha
# Processing Record 9 of Set 7 | lavrentiya
# Processing Record 10 of Set 7 | karasjok
# Processing Record 11 of Set 7 | pahrump
# Processing Record 12 of Set 7 | beringovskiy
# Processing Record 13 of Set 7 | arlit
# Processing Record 14 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 15 of Set 7 | manavalakurichi
# Processing Record 16 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 17 of Set 7 | kupang
# Processing Record 18 of Set 7 | ambalavao
# Processing Record 19 of Set 7 | high level
# Processing Record 20 of Set 7 | krasnovishersk
# Processing Record 21 of Set 7 | aden
# Processing Record 22 of Set 7 | slave lake
# Processing Record 23 of Set 7 | ullapool
# Processing Record 24 of Set 7 | salalah
# Processing Record 25 of Set 7 | barrhead
# Processing Record 26 of Set 7 | roswell
# Processing Record 27 of Set 7 | lodja
# Processing Record 28 of Set 7 | grand gaube
# Processing Record 29 of Set 7 | zhezkazgan
# Processing Record 30 of Set 7 | puerto leguizamo
# Processing Record 31 of Set 7 | half moon bay
# Processing Record 32 of Set 7 | macenta
# Processing Record 33 of Set 7 | saint-pierre
# Processing Record 34 of Set 7 | ulcinj
# Processing Record 35 of Set 7 | angoche
# Processing Record 36 of Set 7 | waiouru
# Processing Record 37 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 7 | flinders
# Processing Record 39 of Set 7 | praia da vitoria
# Processing Record 40 of Set 7 | alofi
# Processing Record 41 of Set 7 | yar-sale
# Processing Record 42 of Set 7 | pemangkat
# Processing Record 43 of Set 7 | rutland
# Processing Record 44 of Set 7 | shenjiamen
# Processing Record 45 of Set 7 | filingue
# Processing Record 46 of Set 7 | terra santa
# Processing Record 47 of Set 7 | sorland
# Processing Record 48 of Set 7 | zhuhai
# Processing Record 49 of Set 7 | esmeralda
# Processing Record 50 of Set 7 | gazanjyk
# Processing Record 1 of Set 8 | mitsamiouli
# Processing Record 2 of Set 8 | mason city
# Processing Record 3 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 8 | bressuire
# Processing Record 5 of Set 8 | rio gallegos
# Processing Record 6 of Set 8 | kaeo
# Processing Record 7 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 8 | upata
# Processing Record 9 of Set 8 | paamiut
# Processing Record 10 of Set 8 | agirish
# Processing Record 11 of Set 8 | northam
# Processing Record 12 of Set 8 | guerrero negro
# Processing Record 13 of Set 8 | namibe
# Processing Record 14 of Set 8 | saint-augustin
# Processing Record 15 of Set 8 | inirida
# Processing Record 16 of Set 8 | junin
# Processing Record 17 of Set 8 | cordoba
# Processing Record 18 of Set 8 | wakkanai
# Processing Record 19 of Set 8 | sao jose de ribamar
# Processing Record 20 of Set 8 | meru
# Processing Record 21 of Set 8 | bonthe
# Processing Record 22 of Set 8 | ballina
# Processing Record 23 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 8 | adrar
# Processing Record 25 of Set 8 | riobamba
# Processing Record 26 of Set 8 | duz
# City not found. Skipping...
# Processing Record 27 of Set 8 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 28 of Set 8 | cayenne
# Processing Record 29 of Set 8 | karratha
# Processing Record 30 of Set 8 | cairns
# Processing Record 31 of Set 8 | gravelbourg
# Processing Record 32 of Set 8 | iesolo
# Processing Record 33 of Set 8 | madison
# Processing Record 34 of Set 8 | uruzgan
# Processing Record 35 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 8 | north bend
# Processing Record 37 of Set 8 | odweyne
# Processing Record 38 of Set 8 | mirnyy
# Processing Record 39 of Set 8 | pasni
# Processing Record 40 of Set 8 | hovd
# Processing Record 41 of Set 8 | ayr
# Processing Record 42 of Set 8 | broome
# Processing Record 43 of Set 8 | wamba
# Processing Record 44 of Set 8 | bud
# Processing Record 45 of Set 8 | nouadhibou
# Processing Record 46 of Set 8 | puchezh
# Processing Record 47 of Set 8 | luba
# Processing Record 48 of Set 8 | aporawan
# City not found. Skipping...
# Processing Record 49 of Set 8 | comodoro rivadavia
# Processing Record 50 of Set 8 | montelibano
# Processing Record 1 of Set 9 | stutterheim
# Processing Record 2 of Set 9 | mahebourg
# Processing Record 3 of Set 9 | lakes entrance
# Processing Record 4 of Set 9 | pingzhuang
# Processing Record 5 of Set 9 | fuente de oro
# Processing Record 6 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 9 | dickinson
# Processing Record 8 of Set 9 | collingwood
# Processing Record 9 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 9 | rahuri
# Processing Record 11 of Set 9 | rayong
# Processing Record 12 of Set 9 | harper
# Processing Record 13 of Set 9 | humberto de campos
# Processing Record 14 of Set 9 | namie
# Processing Record 15 of Set 9 | valley city
# Processing Record 16 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 17 of Set 9 | nakhon thai
# Processing Record 18 of Set 9 | teya
# Processing Record 19 of Set 9 | sibu
# Processing Record 20 of Set 9 | srandakan
# Processing Record 21 of Set 9 | mahibadhoo
# Processing Record 22 of Set 9 | port hedland
# Processing Record 23 of Set 9 | gambela
# Processing Record 24 of Set 9 | grong
# Processing Record 25 of Set 9 | naruja
# Processing Record 26 of Set 9 | stokmarknes
# Processing Record 27 of Set 9 | sovetskiy
# Processing Record 28 of Set 9 | dingle
# Processing Record 29 of Set 9 | touho
# Processing Record 30 of Set 9 | schruns
# Processing Record 31 of Set 9 | batetskiy
# Processing Record 32 of Set 9 | neuquen
# Processing Record 33 of Set 9 | penalva
# Processing Record 34 of Set 9 | tahe
# Processing Record 35 of Set 9 | college
# Processing Record 36 of Set 9 | havre-saint-pierre
# Processing Record 37 of Set 9 | luwuk
# Processing Record 38 of Set 9 | kavaratti
# Processing Record 39 of Set 9 | constantine
# Processing Record 40 of Set 9 | linguere
# Processing Record 41 of Set 9 | husavik
# Processing Record 42 of Set 9 | general roca
# Processing Record 43 of Set 9 | aasiaat
# Processing Record 44 of Set 9 | miri
# Processing Record 45 of Set 9 | marica
# Processing Record 46 of Set 9 | umm kaddadah
# Processing Record 47 of Set 9 | salinopolis
# Processing Record 48 of Set 9 | aklavik
# Processing Record 49 of Set 9 | raudeberg
# Processing Record 50 of Set 9 | sisimiut
# Processing Record 1 of Set 10 | kuruman
# Processing Record 2 of Set 10 | dutse
# Processing Record 3 of Set 10 | visnes
# Processing Record 4 of Set 10 | dicabisagan
# Processing Record 5 of Set 10 | parole
# Processing Record 6 of Set 10 | mahina
# Processing Record 7 of Set 10 | selma
# Processing Record 8 of Set 10 | pyaozerskiy
# Processing Record 9 of Set 10 | warri
# Processing Record 10 of Set 10 | nanortalik
# Processing Record 11 of Set 10 | oriximina
# Processing Record 12 of Set 10 | panukulan
# Processing Record 13 of Set 10 | mollendo
# Processing Record 14 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 10 | bonavista
# Processing Record 16 of Set 10 | fukue
# Processing Record 17 of Set 10 | valentin gomez farias
# Processing Record 18 of Set 10 | oga
# Processing Record 19 of Set 10 | finschhafen
# Processing Record 20 of Set 10 | portland
# Processing Record 21 of Set 10 | handan
# Processing Record 22 of Set 10 | epe
# Processing Record 23 of Set 10 | pouembout
# Processing Record 24 of Set 10 | codrington
# Processing Record 25 of Set 10 | muroto
# Processing Record 26 of Set 10 | jaramana
# City not found. Skipping...
# Processing Record 27 of Set 10 | neiafu
# Processing Record 28 of Set 10 | faya
# Processing Record 29 of Set 10 | san juan del sur
# Processing Record 30 of Set 10 | tanete
# Processing Record 31 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 32 of Set 10 | rajauri
# Processing Record 33 of Set 10 | bacum
# Processing Record 34 of Set 10 | sambava
# Processing Record 35 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 36 of Set 10 | maridi
# Processing Record 37 of Set 10 | surt
# Processing Record 38 of Set 10 | udachnyy
# Processing Record 39 of Set 10 | sukumo
# Processing Record 40 of Set 10 | pangnirtung
# Processing Record 41 of Set 10 | chara
# Processing Record 42 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 43 of Set 10 | jiwani
# Processing Record 44 of Set 10 | leningradskiy
# Processing Record 45 of Set 10 | gombong
# Processing Record 46 of Set 10 | ponta delgada
# Processing Record 47 of Set 10 | nokha
# Processing Record 48 of Set 10 | arys
# Processing Record 49 of Set 10 | bilma
# Processing Record 50 of Set 10 | sal rei
# Processing Record 1 of Set 11 | carutapera
# Processing Record 2 of Set 11 | dunda
# Processing Record 3 of Set 11 | atar
# Processing Record 4 of Set 11 | hofn
# Processing Record 5 of Set 11 | shingu
# Processing Record 6 of Set 11 | porto walter
# Processing Record 7 of Set 11 | manali
# Processing Record 8 of Set 11 | itoman
# Processing Record 9 of Set 11 | talnakh
# Processing Record 10 of Set 11 | huntsville
# Processing Record 11 of Set 11 | iquitos
# Processing Record 12 of Set 11 | bereda
# Processing Record 13 of Set 11 | hambantota
# Processing Record 14 of Set 11 | chenghai
# Processing Record 15 of Set 11 | katangli
# Processing Record 16 of Set 11 | dunedin
# Processing Record 17 of Set 11 | dzhebariki-khaya
# Processing Record 18 of Set 11 | esmeraldas
# Processing Record 19 of Set 11 | hue
# Processing Record 20 of Set 11 | melo
# Processing Record 21 of Set 11 | karaton
# Processing Record 22 of Set 11 | maumere
# Processing Record 23 of Set 11 | lukovetskiy
# Processing Record 24 of Set 11 | menongue
# Processing Record 25 of Set 11 | laguna
# Processing Record 26 of Set 11 | auki
# Processing Record 27 of Set 11 | zhirnovsk
# Processing Record 28 of Set 11 | axim
# Processing Record 29 of Set 11 | biak
# Processing Record 30 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 11 | shache
# Processing Record 32 of Set 11 | caruray
# Processing Record 33 of Set 11 | sosnovo-ozerskoye
# Processing Record 34 of Set 11 | cradock
# Processing Record 35 of Set 11 | muisne
# Processing Record 36 of Set 11 | igrim
# Processing Record 37 of Set 11 | sabha
# Processing Record 38 of Set 11 | brigantine
# Processing Record 39 of Set 11 | awjilah
# Processing Record 40 of Set 11 | tuyen quang
# Processing Record 41 of Set 11 | manzil jamil
# City not found. Skipping...
# Processing Record 42 of Set 11 | marsh harbour
# Processing Record 43 of Set 11 | cap malheureux
# Processing Record 44 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 11 | staunton
# Processing Record 46 of Set 11 | aksu
# Processing Record 47 of Set 11 | san cristobal
# Processing Record 48 of Set 11 | seoul
# Processing Record 49 of Set 11 | elko
# Processing Record 50 of Set 11 | oranjemund
# Processing Record 1 of Set 12 | kyzyl-suu
# Processing Record 2 of Set 12 | gurgan
# City not found. Skipping...
# Processing Record 3 of Set 12 | santa cruz
# Processing Record 4 of Set 12 | vangaindrano
# Processing Record 5 of Set 12 | vostok
# Processing Record 6 of Set 12 | port-cartier
# Processing Record 7 of Set 12 | wattegama
# Processing Record 8 of Set 12 | kayiry
# Processing Record 9 of Set 12 | shirokiy
# Processing Record 10 of Set 12 | sangar
# Processing Record 11 of Set 12 | erzin
# Processing Record 12 of Set 12 | bagotville
# Processing Record 13 of Set 12 | clyde river
# Processing Record 14 of Set 12 | crixas
# Processing Record 15 of Set 12 | port blair
# Processing Record 16 of Set 12 | rodrigues alves
# Processing Record 17 of Set 12 | villanueva de la serena
# Processing Record 18 of Set 12 | bisho
# Processing Record 19 of Set 12 | bahia blanca
# Processing Record 20 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 12 | neyshabur
# Processing Record 22 of Set 12 | surin
# Processing Record 23 of Set 12 | sao filipe
# Processing Record 24 of Set 12 | adeje
# Processing Record 25 of Set 12 | sao joao da barra
# Processing Record 26 of Set 12 | colac
# Processing Record 27 of Set 12 | formosa
# Processing Record 28 of Set 12 | hokitika
# Processing Record 29 of Set 12 | verkhnevilyuysk
# Processing Record 30 of Set 12 | solsvik
# City not found. Skipping...
# Processing Record 31 of Set 12 | henderson
# Processing Record 32 of Set 12 | isangel
# Processing Record 33 of Set 12 | ahipara
# Processing Record 34 of Set 12 | bermejo
# Processing Record 35 of Set 12 | khao yoi
# Processing Record 36 of Set 12 | nemuro
# Processing Record 37 of Set 12 | hami
# Processing Record 38 of Set 12 | les cayes
# Processing Record 39 of Set 12 | moroni
# Processing Record 40 of Set 12 | nishihara
# Processing Record 41 of Set 12 | tchollire
# Processing Record 42 of Set 12 | merauke
# Processing Record 43 of Set 12 | magadan
# Processing Record 44 of Set 12 | xining
# Processing Record 45 of Set 12 | san quintin
# Processing Record 46 of Set 12 | kirgiz-miyaki
# Processing Record 47 of Set 12 | balikpapan
# Processing Record 48 of Set 12 | vila
# Processing Record 49 of Set 12 | taltal
# Processing Record 50 of Set 12 | saldanha
# Processing Record 1 of Set 13 | palmer
# Processing Record 2 of Set 13 | nara
# Processing Record 3 of Set 13 | baoning
# Processing Record 4 of Set 13 | orsha
# Processing Record 5 of Set 13 | pervomaysk
# Processing Record 6 of Set 13 | ringsted
# Processing Record 7 of Set 13 | kingsland
# Processing Record 8 of Set 13 | saint-joseph
# Processing Record 9 of Set 13 | kaardi
# City not found. Skipping...
# Processing Record 10 of Set 13 | skibbereen
# Processing Record 11 of Set 13 | banda aceh
# Processing Record 12 of Set 13 | liwale
# Processing Record 13 of Set 13 | sechura
# Processing Record 14 of Set 13 | kerrville
# Processing Record 15 of Set 13 | tomatlan
# Processing Record 16 of Set 13 | gari
# Processing Record 17 of Set 13 | shimoda
# Processing Record 18 of Set 13 | madingou
# Processing Record 19 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 20 of Set 13 | turayf
# Processing Record 21 of Set 13 | solnechnyy
# Processing Record 22 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 23 of Set 13 | bonfim
# Processing Record 24 of Set 13 | caetite
# Processing Record 25 of Set 13 | kafanchan
# Processing Record 26 of Set 13 | camana
# Processing Record 27 of Set 13 | edgewater
# Processing Record 28 of Set 13 | matagami
# Processing Record 29 of Set 13 | guhagar
# Processing Record 30 of Set 13 | kalmunai
# Processing Record 31 of Set 13 | ternate
# Processing Record 32 of Set 13 | belen
# Processing Record 33 of Set 13 | san vicente
# Processing Record 34 of Set 13 | villablino
# Processing Record 35 of Set 13 | plettenberg bay
# Processing Record 36 of Set 13 | abiy adi
# City not found. Skipping...
# Processing Record 37 of Set 13 | akyab
# Processing Record 38 of Set 13 | azul
# Processing Record 39 of Set 13 | leshukonskoye
# Processing Record 40 of Set 13 | beaupre
# Processing Record 41 of Set 13 | gunjur
# Processing Record 42 of Set 13 | kloulklubed
# Processing Record 43 of Set 13 | zorgo
# Processing Record 44 of Set 13 | berezovyy
# Processing Record 45 of Set 13 | alice springs
# Processing Record 46 of Set 13 | eureka
# Processing Record 47 of Set 13 | champasak
# Processing Record 48 of Set 13 | domoni
# Processing Record 49 of Set 13 | beckley
# Processing Record 50 of Set 13 | show low
# Processing Record 1 of Set 14 | bubaque
# Processing Record 2 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 3 of Set 14 | ararat
# Processing Record 4 of Set 14 | strzelce krajenskie
# Processing Record 5 of Set 14 | ayotzintepec
# Processing Record 6 of Set 14 | olinda
# Processing Record 7 of Set 14 | puerto baquerizo moreno
# Processing Record 8 of Set 14 | rize
# Processing Record 9 of Set 14 | bafoulabe
# Processing Record 10 of Set 14 | lanzhou
# Processing Record 11 of Set 14 | baghdad
# Processing Record 12 of Set 14 | cabedelo
# Processing Record 13 of Set 14 | pacific grove
# Processing Record 14 of Set 14 | tautira
# Processing Record 15 of Set 14 | silifke
# Processing Record 16 of Set 14 | kumluca
# Processing Record 17 of Set 14 | bolvasnita
# City not found. Skipping...
# Processing Record 18 of Set 14 | kitimat
# Processing Record 19 of Set 14 | athabasca
# Processing Record 20 of Set 14 | poum
# Processing Record 21 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 14 | buriti bravo
# Processing Record 23 of Set 14 | hualmay
# Processing Record 24 of Set 14 | wysokie mazowieckie
# Processing Record 25 of Set 14 | oranjestad
# Processing Record 26 of Set 14 | nador
# Processing Record 27 of Set 14 | ruteng
# Processing Record 28 of Set 14 | bairiki
# Processing Record 29 of Set 14 | seguela
# Processing Record 30 of Set 14 | saryagash
# Processing Record 31 of Set 14 | jinchengjiang
# City not found. Skipping...
# Processing Record 32 of Set 14 | erenhot
# Processing Record 33 of Set 14 | mantua
# Processing Record 34 of Set 14 | sinaloa
# Processing Record 35 of Set 14 | kayerkan
# Processing Record 36 of Set 14 | weligama
# Processing Record 37 of Set 14 | khandbari
# Processing Record 38 of Set 14 | kuching
# Processing Record 39 of Set 14 | chiang rai
# Processing Record 40 of Set 14 | moron
# Processing Record 41 of Set 14 | jian
# Processing Record 42 of Set 14 | porto santo
# Processing Record 43 of Set 14 | dudinka
# Processing Record 44 of Set 14 | sibenik
# Processing Record 45 of Set 14 | jiuquan
# Processing Record 46 of Set 14 | vestmannaeyjar
# Processing Record 47 of Set 14 | kemijarvi
# Processing Record 48 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 14 | bafang
# Processing Record 1 of Set 15 | port-gentil
# Processing Record 2 of Set 15 | leh
# Processing Record 3 of Set 15 | acapulco
# Processing Record 4 of Set 15 | ostrovnoy
# Processing Record 5 of Set 15 | shaoyang
# Processing Record 6 of Set 15 | sidney
# Processing Record 7 of Set 15 | quatre cocos
# Processing Record 8 of Set 15 | mercedes
# Processing Record 9 of Set 15 | ambilobe
# Processing Record 10 of Set 15 | nantucket
# Processing Record 11 of Set 15 | baryshevo
# Processing Record 12 of Set 15 | coquimbo
# Processing Record 13 of Set 15 | rancho palos verdes
# Processing Record 14 of Set 15 | lisakovsk
# Processing Record 15 of Set 15 | kungurtug
# Processing Record 16 of Set 15 | tynda
# Processing Record 17 of Set 15 | handia
# Processing Record 18 of Set 15 | ayacucho
# Processing Record 19 of Set 15 | san miguel
# Processing Record 20 of Set 15 | oktyabrskoye
# Processing Record 21 of Set 15 | zhangjiakou
# Processing Record 22 of Set 15 | avera
# Processing Record 23 of Set 15 | qaqortoq
# Processing Record 24 of Set 15 | tabou
# Processing Record 25 of Set 15 | miandrivazo
# Processing Record 26 of Set 15 | haimen
# Processing Record 27 of Set 15 | tambovka
# Processing Record 28 of Set 15 | warangal
# Processing Record 29 of Set 15 | kaele
# Processing Record 30 of Set 15 | tezu
# Processing Record 31 of Set 15 | auray
# Processing Record 32 of Set 15 | gangotri
# City not found. Skipping...
# Processing Record 33 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 34 of Set 15 | copiapo
# Processing Record 35 of Set 15 | bang phae
# Processing Record 36 of Set 15 | crotone
# Processing Record 37 of Set 15 | catuday
# Processing Record 38 of Set 15 | costinesti
# Processing Record 39 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 15 | sussex
# Processing Record 41 of Set 15 | chapleau
# Processing Record 42 of Set 15 | saint-denis
# Processing Record 43 of Set 15 | sitka
# Processing Record 44 of Set 15 | qui nhon
# Processing Record 45 of Set 15 | ginda
# Processing Record 46 of Set 15 | maneadero
# Processing Record 47 of Set 15 | isiolo
# Processing Record 48 of Set 15 | el retorno
# Processing Record 49 of Set 15 | minna
# Processing Record 50 of Set 15 | tall kayf
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
output_city_data_df = pd.DataFrame(city_data)
output_city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Burnie      AU -41.0667  145.9167     61.95        85           9
# 1        Jamestown      US  42.0970  -79.2353     24.12        51         100
# 2            Bakel      SN  14.9050  -12.4568     95.38         7          82
# 3        Cape Town      ZA -33.9258   18.4232     78.12        46           0
# 4          Kavieng      PG  -2.5744  150.7967     82.51        76          36
# 5          Russell      US  32.3502  -85.1999     46.96        67         100
# 6          Mataura      NZ -46.1927  168.8643     49.48        88          67
# 7  Arraial Do Cabo      BR -22.9661  -42.0278     85.96        74          75
# 8             Nome      US  64.5011 -165.4064    -18.33        76           0
# 9   Cabo San Lucas      MX  22.8909 -109.9124     67.51        66          40
#
#    Wind Speed Current Description
# 0        6.20           clear sky
# 1        8.05                mist
# 2        2.62       broken clouds
# 3       29.93           clear sky
# 4        9.15          light rain
# 5        0.00     overcast clouds
# 6        1.99       broken clouds
# 7        8.05       broken clouds
# 8        0.00           clear sky
# 9        3.44    scattered clouds

# %%
output_city_data_df.to_csv("Weather_Database/WeatherPy_Database.csv")
